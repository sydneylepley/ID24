# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
Salary_data = pd.read_csv("Salary data.csv")

# %%
Salary_data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
plt.figure()
sns.scatterplot(x="Age", y="Salary", data=Salary_data)
plt.title('Default Scatter Plot: Age vs Salary')
plt.show()

# %%
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=Salary_data)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's" : "green", "Master's" : "blue", "PhD" : "red"}
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=Salary_data, palette=education_colors)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's" : "green", "Master's" : "blue", "PhD" : "red"}
gender_markers = {"Female" : "o", "Male" : "s"}
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=Salary_data, palette=education_colors, markers=gender_markers)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's" : "green", "Master's" : "blue", "PhD" : "red"}
gender_markers = {"Female" : "o", "Male" : "s"}
plt.figure()
sns.set_style("ticks") 
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=Salary_data, palette=education_colors, markers=gender_markers)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's" : "green", "Master's" : "blue", "PhD" : "red"}
gender_markers = {"Female" : "o", "Male" : "s"}
plt.figure(figsize=(12,8))
sns.set_style("ticks") 
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=Salary_data, palette=education_colors, markers=gender_markers)

plt.legend(ncol=2,frameon=False, loc= "lower right")
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
gender_colors = {"Female" : "hotpink", "Male" : "blue"}

plt.figure(figsize=(12,8))
sns.set_style("ticks") 
Bachelors=sns.scatterplot(x="Age", y="Salary", hue="Gender", data=Salary_data[Salary_data["Education Level"] == "Bachelor's"], palette=gender_colors)
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000,250000)

plt.legend(ncol=2,frameon=False, loc= "lower right")
plt.title("Age vs Salary Based on Gender Among Bachelor's Degree Holders")
plt.show()

# %%
gender_colors = {"Female" : "hotpink", "Male" : "blue"}

plt.figure(figsize=(12,8))
sns.set_style("ticks") 
Bachelors=sns.scatterplot(x="Age", y="Salary", hue="Gender", data=Salary_data[Salary_data["Education Level"] == "Master's"], palette=gender_colors)
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000,250000)

plt.legend(ncol=2,frameon=False, loc= "lower right")
plt.title("Age vs Salary Based on Gender Among Master's Degree Holders")
plt.show()

# %%
gender_colors = {"Female" : "hotpink", "Male" : "blue"}

plt.figure(figsize=(12,8))
sns.set_style("ticks") 
Bachelors=sns.scatterplot(x="Age",\
                          y="Salary",\
                          hue="Gender",\
                          data=Salary_data[Salary_data["Education Level"] == "PhD"], palette=gender_colors)
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000,250000)

plt.legend(ncol=2,frameon=False, loc= "lower right")
plt.title("Age vs Salary Based on Gender Among PhD Degree Holders")
plt.show()

# %%
sns.barplot(x='Years of Experience', y='Education Level', hue= 'Gender', data=Salary_data)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Education Level'>

# %%
sns.barplot(y='Years of Experience', x='Education Level', hue= 'Gender', capsize=0.1, data=Salary_data)
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
sns.barplot(y='Years of Experience', x='Education Level', hue= 'Gender', capsize=0.1, data=Salary_data, errorbar=None)
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
sns.barplot(y='Years of Experience', x='Education Level', hue= 'Gender', capsize=0.1, data=Salary_data, errorbar=None, palette='dark:blue', hue_order= ['Female', 'Male'])
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
sns.boxplot(x='Years of Experience', y='Education Level', hue= 'Gender', data=Salary_data)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Education Level'>

# %%
sns.barplot(y='Years of Experience', x='Education Level', hue= 'Gender', capsize=0.1, data=Salary_data, errorbar=None, palette='hls', hue_order= ['Female', 'Male'])
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>
